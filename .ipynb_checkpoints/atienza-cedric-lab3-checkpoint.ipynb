# %% [markdown]
# Atienza, 190399, 2 BS ITE

# %% [markdown]
# -----------

# %% [markdown]
# Problem 1
#
# Social Media Example
# (6 Points)
#
# In a prototype of a new in-campus mobile app, there is social media support similar to what's seen on Facebook, Instagram and Spotify. Students and Faculty belong to the same social graph. Any student or teacher can follow other members of the app community. If two members follow each other, they are considered friends.
#
# Write a function relationship_status(from_member, to_member) that determines if two members are friends, or if the first person follows or is followed by the second person. The function should return one of these:
#
# "follower" (type is str)
# "followed by"(type is str)
# None (type is None)

# %%
#with input

social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

from_member = input("From: ")
to_member = input("To: ")

#from follows to - to should be in from's following but from should not be in to's following
#from is followed by to - from should be in to's following but to should not be in from's following
#friends - they are in each's following

def relationship_status(from_member,to_member) :
    
    follows = False
    followed = False
    x = ""
    
    if to_member in social_graph[from_member]["following"] :
        follows = True
        
    else :
        follows = False
    
    if from_member in social_graph[to_member]["following"] :
        followed = True
    
    else:
        followed = False
        
    if (follows==True and followed==True) :
        x = "Friends"
    
    elif (follows==True and followed==False) :
        x = "Follows"
    
    elif (follows==False and followed==True) :
        x = "Followed by"
        
    else :
        x = ""
    
    return x

print(relationship_status(from_member,to_member))
# Out:
# From:  @bongolpoc
# To:  @chums
# Followed by

# %%
#without input

social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

#from follows to - to should be in from's following but from should not be in to's following
#from is followed by to - from should be in to's following but to should not be in from's following
#friends - they are in each's following

from_member = "@chums"
to_member = "@jobenilagan"

def relationship_status(from_member,to_member) :
    
    follows = False
    followed = False
    x = ""
    
    if to_member in social_graph[from_member]["following"] :
        follows = True
        
    else :
        follows = False
    
    if from_member in social_graph[to_member]["following"] :
        followed = True
    
    else:
        followed = False
        
    if (follows==True and followed==True) :
        x = "Friends"
    
    elif (follows==True and followed==False) :
        x = "Follows"
    
    elif (follows==False and followed==True) :
        x = "Followed by"
        
    else :
        None
    
    return x

print(relationship_status(from_member,to_member))
# Out:
# Followed by

# %% [markdown]
# --------------

# %% [markdown]
# Problem 2
#
# Write code that checks a possible winner for the current state of a 3x3 tic-tac-toe board.
#
# There are several strategies here:
#
# - Check if any symbol has all three slots in any row, column, or any of the two diagonals
# - Create a set for each row, column and diagonal; if the set count of 1 indicates a winner. (Why?)

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def get_winner(board):
    winner = None
    
    ## check diagonals
    
    x = [board[i][i] for i,v in enumerate(board)]
        
    if all(num == x[0] for num in x):
        winner = x[0]
    
    y = [board[i][2-i] for i,v in enumerate(board)]
        
    if all(num == y[0] for num in y):
        winner = y[0]

    ## check rows
    
    c = 0
    while c < 3:
        z = board[c]
        if all(num == z[0] for num in z):
            winner = z[0]
        c+=1
    
    #z = board[0]
    #if all(num == z[0] for num in z):
    #    winner = z[0]
        
    #u = board[1]
    #if all(num == u[0] for num in u):
      #  winner = u[0]
        
    ##s = board[2]
    #if all(num == s[0] for num in s):
     #   winner = s[0]
        
    
    ## check columns
    
    n=0
    
    while n<3:
        a = [column[n] for column in board]
        if all(num == a[0] for num in a):
            winner = a[0]
        n+=1
    
    #n=0
    #a = [m[n] for m in board]
    #if all(num == a[0] for num in a):
    #    winner = a[0]
    
    #n=1
    #b = [m[n] for m in board]
    #if all(num == b[0] for num in b):
    #    winner = b[0]
        
    #n=2
    #c = [m[n] for m in board]
    #if all(num == c[0] for num in c):
    #    winner = c[0]
    
    
    return winner
    
print(get_winner(board4))
# Out:
# X

# %% [markdown]
# ---------------

# %% [markdown]
# Problem 3
#
# During the pandemic, a shuttle van service is tasked to travel along a predefined circular route as follows:
#
# - UP Diliman->Ateneo de Manila (Estimated Time: 10 mins)
# - Ateneo de Manila->De La Salle Taft (Estimated Time: 35 mins)
# - De La Salle Taft->UP Diliman (Estimated Time: 55 mins)
#
# The route is one-way only. So, the van cannot go back directly to UP Diliman from Ateneo de Manila; rather, it will have to drop by De La Salle Taft first before going to UP Diliman.
#
# Write a function called eta that accepts the source and destination of the van and returns the estimated number of minutes to reach the destination.

# %%
#turning keys into a list

locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{ #0
         "travel_time_mins":10
     },
     ("admu","dlsu"):{ #1
         "travel_time_mins":35
     },
     ("dlsu","upd"):{ #2
         "travel_time_mins":55
     }
}

source=input("Enter source: ")
destination=input("Enter destination: ")

def eta(source,destination):

    totalTime = 0
    
    if(source==destination):
        totalTime = 0
    
    else:
    
        #turn keys into list
        keyList = list(legs.keys())

        #get first item in list for source
        sourceIndex = 0
        c=0
        while c<3:
            x=keyList[c][0]
            if(x==source):
                sourceIndex = c
            c+=1

        #get second item in list for destination
        destiIndex = 0
        d=0
        while d<3:
            y=keyList[d][1]
            if(y==destination):
                destiIndex = d
            d+=1

        #get key from list
        sourceKey = keyList[sourceIndex]
        destiKey = keyList[destiIndex]

        totalTime = legs[sourceKey]["travel_time_mins"] + legs[destiKey]["travel_time_mins"]
    
    return totalTime

print(eta(source,destination))
# Out:
# Enter source:  dlsu
# Enter destination:  admu
# 65

# %%
#manual if-elif

locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{ #0
         "travel_time_mins":10
     },
     ("admu","dlsu"):{ #1
         "travel_time_mins":35
     },
     ("dlsu","upd"):{ #2
         "travel_time_mins":55
     }
}

source=input("Enter source: ")
destination=input("Enter destination: ")

def eta(source,destination):
    
    timeDiff = 0
    
    if(source == destination):
        timeDiff = 0
        
    else:
    
        if(source == "upd"):
            source = ("upd","admu")

        elif(source == "admu"):
            source = ("admu","dlsu")

        elif(source == "dlsu"):
            source = ("dlsu","upd")

        if(destination == "admu"):
            destination = ("upd","admu")

        elif(destination == "dlsu"):
            destination = ("admu","dlsu")

        elif(destination == "upd"):
            destination = ("dlsu","upd")
    
        timeDiff = legs[source]["travel_time_mins"] + legs[destination]["travel_time_mins"]
    
    return timeDiff

print(eta(source,destination))
# Out:
# Enter source:  admu
# Enter destination:  upd
# 90
